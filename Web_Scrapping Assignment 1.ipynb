# %% [markdown]
#  website link "https://en.wikipedia.org/wiki/List_of_best-selling_books"

# %% [markdown]
# Importing the libraries

# %%
import matplotlib.pyplot as plt  
import pandas as pd 
import requests
from bs4 import BeautifulSoup as bs
import seaborn as sns

# %% [markdown]
# Feteching the main URL

# %%
url_of_wikipida  = "https://en.wikipedia.org/wiki/List_of_best-selling_books"
getting_url = requests.get(url_of_wikipida).text # requesting the webpage and getting the text of html

# %% [markdown]
# Feeding the HTML to beautifulSoup

# %%
so = bs(getting_url) # parsing the html for data gathering

# %% [markdown]
# Finding the Table

# %%
tab  = so.find_all("tbody") #  finding all the tbody tags and then the table

# %%
#Fetching the Data From Each table

# main list of the books
top_99_books = []


# form table 1
table1 = tab[0].find_all('tr') # then all the rows of first columns
for r in table1[1:]:
    t1 = r.find_all('td')
    t2 = [e.text.strip() for e in t1]
    top_99_books.append([e for e in t2 if e])


# form table 2
table2 = tab[1].find_all('tr')
for r in table2[1:]:
    t1 = r.find_all('td')
    t2 = [ele.text.strip() for ele in t1]
    top_99_books.append([e for e in t2 if e])

# form table 3 
table3 = tab[2].find_all('tr')
t2 = []
for r in table3[1:68]:
    t1 = r.find_all('td')
    t2 = [ele.text.strip() for ele in t1]
    top_99_books.append([e for e in t2 if e])

print("------------------------------------ Fetched Data------------------------------------")
# Out:
# ------------------------------------ Fetched Data------------------------------------

# %% [markdown]
# Storing the Data in the DataFrame

# %%
da = pd.DataFrame(top_99_books,columns= ['Book_Name','Author',"Language","Publish Date","No_of_copies_in_millions","Gener"])
da
# Out:
#                                             Book_Name  \
# 0                                A Tale of Two Cities
# 1                                   The Little Prince
# 2            Harry Potter and the Philosopher's Stone
# 3                            And Then There Were None
# 4                            Dream of the Red Chamber
# ..                                                ...
# 95          The Secret Diary of Adrian Mole, Aged 13¾
# 96                                Pride and Prejudice
# 97  Kon-Tiki: Across the Pacific in a Raft (Kon-Ti...
# 98  The Good Soldier Švejk (Osudy dobrého vojáka Š...
# 99                          Where the Wild Things Are
#
#                       Author   Language Publish Date  \
# 0            Charles Dickens    English         1859
# 1   Antoine de Saint-Exupéry     French         1943
# 2              J. K. Rowling    English         1997
# 3            Agatha Christie    English         1939
# 4                 Cao Xueqin    Chinese         1791
# ..                       ...        ...          ...
# 95              Sue Townsend    English         1982
# 96               Jane Austen    English         1813
# 97            Thor Heyerdahl  Norwegian         1950
# 98            Jaroslav Hašek      Czech         1923
# 99            Maurice Sendak    English         1963
#
#                 No_of_copies_in_millions  \
# 0   200 million[19][circular reporting?]
# 1                    200 million[20][21]
# 2                    120 million[22][23]
# 3                        100 million[24]
# 4                    100 million[25][26]
# ..                                   ...
# 95                       20 million[116]
# 96                  20 million[117][118]
# 97                       20 million[119]
# 98             20 million (printed)[120]
# 99                       20 million[121]
#
#                                      Gener
# 0                       Historical fiction
# 1                                  Novella
# 2                                  Fantasy
# 3                                  Mystery
# 4                              Family saga
# ..                                     ...
# 95                       Young adult novel
# 96          Classic regency novel, romance
# 97                       Travel literature
# 98  Unfinished satirical dark comedy novel
# 99                 Children's picture book
#
# [100 rows x 6 columns]

# %% [markdown]
# Using regx for converting string to digit for the number of copies column

# %%
da["No_of_copies_in_millions"] = da["No_of_copies_in_millions"].str.extract(r'(\d+\.?\d*)', expand=False)

# %% [markdown]
# Finding the link of each book

# %%
links_of_books = [] # storing the links in the list 
for i in so.select("td:nth-of-type(1) a")[1:101]: # as we want 100 book so i have specified the number of rows, it means the from 1st column fetech the link 
    links_of_books.append("https://en.wikipedia.org"+i['href'])

links_of_books
# Out:
# ['https://en.wikipedia.org/wiki/The_Little_Prince',
#  'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Philosopher%27s_Stone',
#  'https://en.wikipedia.org/wiki/And_Then_There_Were_None',
#  'https://en.wikipedia.org/wiki/Dream_of_the_Red_Chamber',
#  'https://en.wikipedia.org/wiki/The_Hobbit',
#  'https://en.wikipedia.org/wiki/The_Lion,_the_Witch_and_the_Wardrobe',
#  'https://en.wikipedia.org/wiki/She:_A_History_of_Adventure',
#  'https://en.wikipedia.org/wiki/Vardi_Wala_Gunda',
#  'https://en.wikipedia.org/wiki/The_Da_Vinci_Code',
#  'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Chamber_of_Secrets',
#  'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Prisoner_of_Azkaban',
#  'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Goblet_of_Fire',
#  'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Order_of_the_Phoenix',
#  'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Half-Blood_Prince',
#  'https://en.wikipedia.org/wiki/Harry_Potter_and_the_Deathly_Hallows',
#  'https://en.wikipedia.org/wiki/The_Alchemist_(novel)',
#  'https://en.wikipedia.org/wiki/The_Catcher_in_the_Rye',
#  'https://en.wikipedia.org/wiki/The_Bridges_of_Madison_County',
#  'https://en.wikipedia.org/wiki/Ben-Hur:_A_Tale_of_the_Christ',
#  'https://en.wikipedia.org/wiki/You_Can_Heal_Your_Life',
#  'https://en.wikipedia.org/wiki/One_Hundred_Years_of_Solitude',
#  'https://en.wikipedia.org/wiki/Lolita',
#  'https://en.wikipedia.org/wiki/Heidi',
#  'https://en.wikipedia.org/wiki/The_Common_Sense_Book_of_Baby_and_Child_Care',
#  'https://en.wikipedia.org/wiki/Anne_of_Green_Gables',
#  'https://en.wikipedia.org/wiki/Black_Beauty',
#  'https://en.wikipedia.org/wiki/The_Name_of_the_Rose',
#  'https://en.wikipedia.org/wiki/The_Eagle_Has_Landed_(novel)',
#  'https://en.wikipedia.org/wiki/Watership_Down',
#  'https://en.wikipedia.org/wiki/The_Hite_Report',
#  'https://en.wikipedia.org/wiki/Charlotte%27s_Web',
#  'https://en.wikipedia.org/wiki/The_Ginger_Man',
#  'https://en.wikipedia.org/wiki/The_Tale_of_Peter_Rabbit',
#  'https://en.wikipedia.org/wiki/Jonathan_Livingston_Seagull',
#  'https://en.wikipedia.org/wiki/The_Very_Hungry_Caterpillar',
#  'https://en.wikipedia.org/wiki/A_Message_to_Garcia',
#  'https://en.wikipedia.org/wiki/To_Kill_a_Mockingbird',
#  'https://en.wikipedia.org/wiki/Flowers_in_the_Attic',
#  'https://en.wikipedia.org/wiki/Cosmos_(Carl_Sagan_book)',
#  'https://en.wikipedia.org/wiki/Sophie%27s_World',
#  'https://en.wikipedia.org/wiki/Angels_%26_Demons',
#  'https://en.wikipedia.org/wiki/Kane_and_Abel_(novel)',
#  'https://en.wikipedia.org/wiki/How_the_Steel_Was_Tempered',
#  'https://en.wikipedia.org/wiki/War_and_Peace',
#  'https://en.wikipedia.org/wiki/The_Adventures_of_Pinocchio',
#  'https://en.wikipedia.org/wiki/The_Diary_of_a_Young_Girl',
#  'https://en.wikipedia.org/wiki/Your_Erroneous_Zones',
#  'https://en.wikipedia.org/wiki/The_Thorn_Birds',
#  'https://en.wikipedia.org/wiki/The_Purpose_Driven_Life',
#  'https://en.wikipedia.org/wiki/The_Kite_Runner',
#  'https://en.wikipedia.org/wiki/Valley_of_the_Dolls_(novel)',
#  'https://en.wikipedia.org/wiki/The_Big_Book_(Alcoholics_Anonymous)',
#  'https://en.wikipedia.org/wiki/How_to_Win_Friends_and_Influence_People',
#  'https://en.wikipedia.org/wiki/The_Great_Gatsby',
#  'https://en.wikipedia.org/wiki/Gone_with_the_Wind_(novel)',
#  'https://en.wikipedia.org/wiki/Rebecca_(novel)',
#  'https://en.wikipedia.org/wiki/Nineteen_Eighty-Four',
#  'https://en.wikipedia.org/wiki/The_Revolt_of_Mamie_Stover',
#  'https://en.wikipedia.org/wiki/The_Girl_with_the_Dragon_Tattoo',
#  'https://en.wikipedia.org/wiki/The_Lost_Symbol',
#  'https://en.wikipedia.org/wiki/The_Hunger_Games_(novel)',
#  'https://en.wikipedia.org/wiki/James_and_the_Giant_Peach',
#  'https://en.wikipedia.org/wiki/The_Young_Guard_(novel)',
#  'https://en.wikipedia.org/wiki/Who_Moved_My_Cheese%3F',
#  'https://en.wikipedia.org/wiki/A_Brief_History_of_Time',
#  'https://en.wikipedia.org/wiki/Paul_et_Virginie',
#  'https://en.wikipedia.org/wiki/Lust_for_Life_(novel)',
#  'https://en.wikipedia.org/wiki/The_Wind_in_the_Willows',
#  'https://en.wikipedia.org/wiki/The_7_Habits_of_Highly_Effective_People',
#  'https://en.wikipedia.org/w/index.php?title=Virgin_Soil_Upturned_(novel)&action=edit&redlink=1',
#  'https://en.wikipedia.org/wiki/The_Celestine_Prophecy',
#  'https://en.wikipedia.org/wiki/The_Fault_in_Our_Stars',
#  'https://en.wikipedia.org/wiki/The_Girl_on_the_Train_(novel)',
#  'https://en.wikipedia.org/wiki/The_Shack_(Young_novel)',
#  'https://en.wikipedia.org/wiki/Uncle_Styopa',
#  'https://en.wikipedia.org/wiki/The_Godfather_(novel)',
#  'https://en.wikipedia.org/wiki/Love_Story_(novel)',
#  'https://en.wikipedia.org/wiki/Catching_Fire',
#  'https://en.wikipedia.org/wiki/Mockingjay',
#  'https://en.wikipedia.org/wiki/Kitchen_(novel)',
#  'https://en.wikipedia.org/wiki/Andromeda_(novel)',
#  'https://en.wikipedia.org/wiki/Autobiography_of_a_Yogi',
#  'https://en.wikipedia.org/wiki/Gone_Girl_(novel)',
#  'https://en.wikipedia.org/wiki/All_Quiet_on_the_Western_Front',
#  'https://en.wikipedia.org/wiki/The_Bermuda_Triangle_(book)',
#  'https://en.wikipedia.org/wiki/Things_Fall_Apart',
#  'https://en.wikipedia.org/wiki/Animal_Farm',
#  'https://en.wikipedia.org/wiki/Wolf_Totem',
#  'https://en.wikipedia.org/wiki/The_Happy_Hooker',
#  'https://en.wikipedia.org/wiki/Jaws_(novel)',
#  'https://en.wikipedia.org/wiki/Love_You_Forever',
#  'https://en.wikipedia.org/wiki/The_Women%27s_Room',
#  'https://en.wikipedia.org/wiki/What_to_Expect_When_You%27re_Expecting',
#  'https://en.wikipedia.org/wiki/Adventures_of_Huckleberry_Finn',
#  'https://en.wikipedia.org/wiki/The_Secret_Diary_of_Adrian_Mole,_Aged_13%C2%BE',
#  'https://en.wikipedia.org/wiki/Pride_and_Prejudice',
#  'https://en.wikipedia.org/wiki/The_Kon-Tiki_Expedition:_By_Raft_Across_the_South_Seas',
#  'https://en.wikipedia.org/wiki/The_Good_Soldier_%C5%A0vejk',
#  'https://en.wikipedia.org/wiki/Where_the_Wild_Things_Are',
#  'https://en.wikipedia.org/wiki/The_Power_of_Positive_Thinking']

# %% [markdown]
# Navigating to the books link <br>
# requesting each book link and then fetech some lines from that book page

# %%
some_info_of_book = []
for i in links_of_books:
    r = requests.get(i).text
    b = bs(r)
    x = " "
    for t in b.find_all('p'):
            x = t.text
    some_info_of_book.append([x])
    
print(some_info_of_book)
# Out:
# [['Since 2020, June 29 is International Little Prince Day. This date was chosen to commemorate the birth of Antoine de Saint-Exupéry, which occurred on June 29, 1900. The Antoine de Saint-Exupéry Foundation started the initiative striving to promote the humanist values \u200b\u200bcarried by the book published in 1943. Mark Osborne was one of the first personalities to participate in the Little Prince Day 2020.[159]\n'], ['Stephen Brown noted that the early Harry Potter books, especially Harry Potter and the Philosopher\'s Stone, were a runaway success despite inadequate and poorly organised marketing. Brown advised marketing executives to be less preoccupied with rigorous statistical analyses and the "analysis, planning, implementation, and control" model of management. Instead he recommended that they should treat the stories as "a marketing masterclass", full of enticing products and brand names.[52] For example, a real-world analogue of Bertie Bott\'s Every Flavour Beans was introduced under licence in 2000 by toymaker Hasbro.[52][94]\n'], ['The 2014 live action comedy-crime and murder mystery TV web series Ten Little Roosters, produced by American company Rooster Teeth, is largely inspired by And Then There Were None.[61]\n'], ['An English-language opera based on the novel in two acts was composed by Chinese American composer Bright Sheng, with libretto by Sheng and David Henry Hwang. The three-hour opera had its world premiere on 10 September 2016, by the San Francisco Opera. For their 2020 album, Transience of Life, the American art-rock band Elysian Fields set several poems from the novel to music.\n'], ['While reliable figures are difficult to obtain, estimated global sales of The Hobbit run between 35[100] and 100[137] million copies since 1937. In the UK The Hobbit has not retreated from the top 5,000 bestselling books measured by Nielsen BookScan since 1998, when the index began,[138] achieving a three-year sales peak rising from 33,084 (2000) to 142,541 (2001), 126,771 (2002) and 61,229 (2003), ranking it at the 3rd position in Nielsen\'s "Evergreen" book list.[139] The enduring popularity of The Hobbit makes early printings of the book attractive collectors\' items. The first printing of the first English-language edition can sell for between £6,000 and £20,000 at auction,[140][141] although the price for a signed first edition has reached over £60,000.[137]\n'], ['In 2005, the story was adapted for a theatrical film, co-produced by Walt Disney Pictures and Walden Media.[81] It was followed by two more films: The Chronicles of Narnia: Prince Caspian and The Chronicles of Narnia: The Voyage of the Dawn Treader,[82] the latter of which was produced by 20th Century Fox instead of Disney.[83]\n'], ['\n'], ['Sharma was awarded the Meerut Ratna twice (1992 and 1994). He had received various state-level awards including the Natraj Bhushan Award in 2008 and the Natraj Award in 1995.\n'], ['The film received two sequels: Angels & Demons, released in 2009, and Inferno, released in 2016. Ron Howard returned to direct both sequels.\n'], ['Five unique video games by different developers were released between 2002 and 2003 by Electronic Arts, loosely based on the book:\n'], ['Three unique video games by different developers were released in 2004 by Electronic Arts, loosely based on the book:\n'], ['It was also made into a video game for PC, PlayStation 2, Nintendo DS, Nintendo GameCube, Xbox, Game Boy Advance, and PlayStation Portable by Electronic Arts. It was released just before the film.\n'], ['The first official foreign translation of the book appeared in Vietnamese on 21 July 2003, when the first of twenty-two instalments was released. The first official European translation appeared in Serbia and Montenegro in Serbian by the official publisher Narodna Knjiga in early September 2003. Other translations appeared later (e.g. in November 2003 in Dutch and German). The English-language version has topped the bestseller list  ...

# %% [markdown]
# Storing the Book info in the dataframe

# %%
da["Book Info"] = some_info_of_book
da
# Out:
#                                             Book_Name  \
# 0                                A Tale of Two Cities
# 1                                   The Little Prince
# 2            Harry Potter and the Philosopher's Stone
# 3                            And Then There Were None
# 4                            Dream of the Red Chamber
# ..                                                ...
# 95          The Secret Diary of Adrian Mole, Aged 13¾
# 96                                Pride and Prejudice
# 97  Kon-Tiki: Across the Pacific in a Raft (Kon-Ti...
# 98  The Good Soldier Švejk (Osudy dobrého vojáka Š...
# 99                          Where the Wild Things Are
#
#                       Author   Language Publish Date No_of_copies_in_millions  \
# 0            Charles Dickens    English         1859                      200
# 1   Antoine de Saint-Exupéry     French         1943                      200
# 2              J. K. Rowling    English         1997                      120
# 3            Agatha Christie    English         1939                      100
# 4                 Cao Xueqin    Chinese         1791                      100
# ..                       ...        ...          ...                      ...
# 95              Sue Townsend    English         1982                       20
# 96               Jane Austen    English         1813                       20
# 97            Thor Heyerdahl  Norwegian         1950                       20
# 98            Jaroslav Hašek      Czech         1923                       20
# 99            Maurice Sendak    English         1963                       20
#
#                                      Gener  \
# 0                       Historical fiction
# 1                                  Novella
# 2                                  Fantasy
# 3                                  Mystery
# 4                              Family saga
# ..                                     ...
# 95                       Young adult novel
# 96          Classic regency novel, romance
# 97                       Travel literature
# 98  Unfinished satirical dark comedy novel
# 99                 Children's picture book
#
#                                             Book Info
# 0   [Since 2020, June 29 is International Little P...
# 1   [Stephen Brown noted that the early Harry Pott...
# 2   [The 2014 live action comedy-crime and murder ...
# 3   [An English-language opera based on the novel ...
# 4   [While reliable figures are difficult to obtai...
# ..                                                ...
# 95  [In summer 2014, Udon Entertainment's Manga Cl...
# 96  [This article about an anthropology-related bo...
# 97  [The first translation by Paul Selver was heav...
# 98  [In 2016, Alessia Cara released her second sin...
# 99  [A Texas woman named Helen Hadsell read the bo...
#
# [100 rows x 7 columns]

# %%
# making a csv file of the dataframe
file_of_data = da.to_csv("DATA.csv")

# %% [markdown]
# Graph<br>
# Bar Graph between no of copies of each book

# %% [markdown]
# first converting the no of copies column in float

# %%
l = da.No_of_copies_in_millions.values.tolist()
a  = []
for i in l:
    a.append(float(i)) # converting to the float


# feeding back to dataframe
da['No_of_copies_in_millions'] = a
da
# Out:
#                                             Book_Name  \
# 0                                A Tale of Two Cities
# 1                                   The Little Prince
# 2            Harry Potter and the Philosopher's Stone
# 3                            And Then There Were None
# 4                            Dream of the Red Chamber
# ..                                                ...
# 95          The Secret Diary of Adrian Mole, Aged 13¾
# 96                                Pride and Prejudice
# 97  Kon-Tiki: Across the Pacific in a Raft (Kon-Ti...
# 98  The Good Soldier Švejk (Osudy dobrého vojáka Š...
# 99                          Where the Wild Things Are
#
#                       Author   Language Publish Date  \
# 0            Charles Dickens    English         1859
# 1   Antoine de Saint-Exupéry     French         1943
# 2              J. K. Rowling    English         1997
# 3            Agatha Christie    English         1939
# 4                 Cao Xueqin    Chinese         1791
# ..                       ...        ...          ...
# 95              Sue Townsend    English         1982
# 96               Jane Austen    English         1813
# 97            Thor Heyerdahl  Norwegian         1950
# 98            Jaroslav Hašek      Czech         1923
# 99            Maurice Sendak    English         1963
#
#     No_of_copies_in_millions                                   Gener  \
# 0                      200.0                      Historical fiction
# 1                      200.0                                 Novella
# 2                      120.0                                 Fantasy
# 3                      100.0                                 Mystery
# 4                      100.0                             Family saga
# ..                       ...                                     ...
# 95                      20.0                       Young adult novel
# 96                      20.0          Classic regency novel, romance
# 97                      20.0                       Travel literature
# 98                      20.0  Unfinished satirical dark comedy novel
# 99                      20.0                 Children's picture book
#
#                                             Book Info
# 0   [Since 2020, June 29 is International Little P...
# 1   [Stephen Brown noted that the early Harry Pott...
# 2   [The 2014 live action comedy-crime and murder ...
# 3   [An English-language opera based on the novel ...
# 4   [While reliable figures are difficult to obtai...
# ..                                                ...
# 95  [In summer 2014, Udon Entertainment's Manga Cl...
# 96  [This article about an anthropology-related bo...
# 97  [The first translation by Paul Selver was heav...
# 98  [In 2016, Alessia Cara released her second sin...
# 99  [A Texas woman named Helen Hadsell read the bo...
#
# [100 rows x 7 columns]

# %% [markdown]
# Now it;s time for the graph

# %%
plt.figure(figsize=(20,50))
plt.title("Graph")
a = sns.barplot(x = da.Book_Name ,y = da.No_of_copies_in_millions ,data= da)
plt.xlabel("Books")
plt.ylabel("No of Copies")
for i in a.containers:
    a.bar_label(i)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
# c:\Users\dell\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 29436 (\N{CJK UNIFIED IDEOGRAPH-72FC}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\dell\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 22270 (\N{CJK UNIFIED IDEOGRAPH-56FE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# c:\Users\dell\anaconda3\lib\site-packages\IPython\core\pylabtools.py:151: UserWarning: Glyph 33150 (\N{CJK UNIFIED IDEOGRAPH-817E}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
